# %% [markdown]
# # Model Hypothesis
# 1. Insiders perspective:
# An insider seeks profit in making insider buyback.
# The more the buyback, the higher confidence he has – using his material insider information.

# %% [markdown]
# 2. Our perspective:
# The fundamentals: return, profitability, valuation, risk factors, etc.
# The ‘better’ the fundamentals, the more convincing the insider ‘endorsement’ from part 1.

# %% [markdown]
# 1+2: The ideal stocks (buy signals) appear when those two perspectives and evaluations match.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import LassoCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import PCA
from sklearn.impute import SimpleImputer

# %%
# load the dataset into Python
df = pd.read_csv('INSIDER_CUSTM_3_26_csv.csv', delimiter=',')

# drop the top 1 blank row & bottom 10 N/A rows
df = df.drop(0)
df = df.drop(df.tail(11).index)
df
# in demand of data cleaning
# Out:
#      Symbol                                               Name  \
# 1      FLWS                    1-800-FLOWERS.COM, Inc. Class A
# 2      VCXA   10x Capital Venture Acquisition Corp. II Class A
# 3       TXG                           10x Genomics Inc Class A
# 4        YI                    111, Inc. Sponsored ADR Class A
# 5        YQ  17 Education & Technology Group, Inc. Unsponso...
# ...     ...                                                ...
# 5098   CNET                    ZW Data Action Technologies Inc
# 5099   ZYME                                      Zymeworks Inc
# 5100   ZYNE                        Zynerba Pharmaceuticals Inc
# 5101   ZYXI                                        Zynex, Inc.
# 5102   ZVSA                         ZyVersa Therapeutics, Inc.
#
#       Sec Market Value (LOCAL)  Com Shs to Calc Diluted EPS  \
# 1                   399.608000                    65.617000
# 2                   210.693390                    27.321667
# 3                  4879.304700                   113.858684
# 4                   131.150280                    83.317060
# 5                    47.474472                    49.405570
# ...                        ...                          ...
# 5098                 14.474381                     6.609784
# 5099                525.138500                    65.249184
# 5100                 20.246380                    39.259495
# 5101                402.612730                    39.127000
# 5102                 19.798590                    16.293460
#
#       LST Num Shs Purch_0M  LST Num Shs Purch_1M  LST Num Shs Purch_2M  \
# 1                      NaN                   0.0                   NaN
# 2                      NaN                   NaN                   NaN
# 3                      0.0                   0.0                   NaN
# 4                      NaN                   NaN                   NaN
# 5                      NaN                   NaN                   NaN
# ...                    ...                   ...                   ...
# 5098                   NaN                   NaN                   NaN
# 5099                   0.0                   NaN             2318900.0
# 5100                   NaN                   0.0                   0.0
# 5101                   0.0                   0.0                   0.0
# 5102                   NaN                   NaN                   0.0
#
#       LST Num Shs Purch_3M  LST Num Shs Purch_4M  LST Num Shs Purch_5M  ...  \
# 1                      0.0                   0.0                   NaN  ...
# 2                      NaN                   NaN                   NaN  ...
# 3                      0.0                   0.0                   NaN  ...
# 4                      NaN                   NaN                   NaN  ...
# 5                      NaN                   NaN                   NaN  ...
# ...                    ...                   ...                   ...  ...
# 5098                   NaN                   NaN                   NaN  ...
# 5099                   0.0                   0.0                   0.0  ...
# 5100                   NaN                   NaN                   NaN  ...
# 5101                   0.0                   0.0                   0.0  ...
# 5102                   0.0                   NaN                   NaN  ...
#
#       Price /Sales CFY  Price / Earns Ratio  Price / Book Value  \
# 1             0.285009            21.249723            1.214968
# 2                  NaN                  NaN            1.383362
# 3             8.034349                  NaN            5.209733
# 4             0.125350                  NaN                 NaN
# 5             0.182325                  NaN            0.421535
# ...                ...                  ...                 ...
# 5098          0.698295                  NaN            1.623298
# 5099          1.243348             4.132275            1.028174
# 5100               NaN                  NaN            1.673961
# 5101          3.441025            31.925637            7.719286
# 5102               NaN                  NaN                 NaN
#
#       Entrpr Value/ Sales  Entrpr Value/ EBITDA  Entrpr Value/ EBIT  \
# 1                0.406217              8.289439           17.830235
# 2                     NaN                   NaN                 NaN
# 3                7.380912                   NaN                 NaN
# 4                0.155423                   NaN                 NaN
# 5               -0.296504                   NaN                 NaN
# ...                   ...                   ...                 ...
# 5098             0.597404                   NaN                 NaN
# 5099             0.118201              0.137113            0.148916
# 5100                  NaN                   NaN                 NaN
# 5101             3.484112             19.916418           23.326121
# 5102                  NaN                   NaN                 NaN
#
#       Div Yield  Total Debt% Equity  EBIT Interest Coverage  Current Ratio
# 1           0.0           58.710781                7.524440       1.310658
# 2           0.0            0.000000                     NaN       1.292346
# 3           0.0           11.812203             -343.966387       4.849187
# 4           NaN                 NaN              -27.110394       1.187411
# 5           0.0           18.470182                     NaN       1.965760
# ...         ...                 ...                     ...            ...
# 5098        0.0           11.017183                     NaN       2.258021
# 5099        NaN            5.706189                     NaN       5.696272
# 5100        0.0            0.793591                     NaN       8.085458
# 5101        0.0           40.626601               52.131818       3.298824
# 5102        NaN                 NaN               -9.379960       0.059575
#
# [5102 rows x 33 columns]

# %% [markdown]
# # Insider Buying attributes:
# Sec Market Value (LOCAL), Com Shs to Calc Diluted EPS, LST Num Shs Purch_0M, LST Num Shs Purch_1M, LST Num Shs Purch_2M, LST Num Shs Purch_3M, LST Num Shs Purch_4M, LST Num Shs Purch_5M, LST Num Shs Purch_6M

# %% [markdown]
# # Return attributes:
# Closing Price_latest, Closing Price_5D, Closing Price_1M, Closing Price_3M, Closing Price_6M, Closing Price_1Y

# %% [markdown]
# # Profitability attributes:
# EBITDA Margin, EBIT Margin, Net Income Margin, ROA, ROE, ROIC, Asset Turnover

# %% [markdown]
# # Valuation attributes:
# Price /Sales CFY, Price / Earns Ratio, Price / Book Value, Entrpr Value/ Sales, Entrpr Value/ EBITDA, Entrpr Value/ EBIT

# %% [markdown]
# # Management & Risk factors attributes:
# Div Yield, Total Debt% Equity, EBIT Interest Coverage, Current Ratio

# %%
# Clean the dataset

# 1. drop rows that contain missing values of 'insider buying' & 'return'
df.dropna(subset=['Com Shs to Calc Diluted EPS'], inplace=True)
df.dropna(subset=['Close Price_latest', 'Close Price_1M', 'Close Price_3M', 'Close Price_6M', 'Close Price_1Y'], inplace=True)
# dropped 272 rows

# 2. drop rows that have closing price of zero
df = df[(df[['Close Price_latest', 'Close Price_1M', 'Close Price_3M', 'Close Price_6M', 'Close Price_1Y']] != 0).all(axis=1)]
# unchanged

# %%
# 3. convert the unit of 'millions'
df["Com Shs to Calc Diluted EPS"] = df["Com Shs to Calc Diluted EPS"] * 1000000
df["Sec Market Value (LOCAL)"] = df["Sec Market Value (LOCAL)"] * 1000000

# %%
# 4. replace with zero for missing 'LST Num Shs Purch'
df[['LST Num Shs Purch_0M', 'LST Num Shs Purch_1M', 'LST Num Shs Purch_2M', 'LST Num Shs Purch_3M', 'LST Num Shs Purch_4M', 'LST Num Shs Purch_5M', 'LST Num Shs Purch_6M']] = df [['LST Num Shs Purch_0M', 'LST Num Shs Purch_1M', 'LST Num Shs Purch_2M', 'LST Num Shs Purch_3M', 'LST Num Shs Purch_4M', 'LST Num Shs Purch_5M', 'LST Num Shs Purch_6M']].fillna(0)

# add them up to get ALL insider purchase within the last 6 months
df['Total Insider Purchases'] = df[['LST Num Shs Purch_0M', 'LST Num Shs Purch_1M', 'LST Num Shs Purch_2M', 
                                    'LST Num Shs Purch_3M', 'LST Num Shs Purch_4M', 'LST Num Shs Purch_5M', 
                                    'LST Num Shs Purch_6M']].sum(axis=1)

df = df.drop(['LST Num Shs Purch_0M', 'LST Num Shs Purch_1M', 'LST Num Shs Purch_2M', 'LST Num Shs Purch_3M', 'LST Num Shs Purch_4M', 'LST Num Shs Purch_5M', 'LST Num Shs Purch_6M'], axis=1)

# %%
df['Total Insider Purchases'].describe()
# Out:
# count    4.830000e+03
# mean     2.624854e+05
# std      6.269918e+06
# min     -7.000000e+03
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      2.432500e+03
# max      4.002133e+08
# Name: Total Insider Purchases, dtype: float64

# %%
# 5. deal with untransparent stocks 
# drop the rows which have more than 70% missing values
threshold = len(df.columns) * 0.7  # set threshold to 70% of total columns
df = df.dropna(thresh=threshold)
df
# 5102 to 3686 rows
# Out:
#      Symbol                                    Name  Sec Market Value (LOCAL)  \
# 1      FLWS         1-800-FLOWERS.COM, Inc. Class A              3.996080e+08
# 3       TXG                10x Genomics Inc Class A              4.879305e+09
# 9      SRCE                  1st Source Corporation              1.109552e+09
# 10     DIBS                       1stdibs.com, Inc.              1.472556e+08
# 11     XXII                22nd Century Group, Inc.              1.615408e+08
# ...     ...                                     ...                       ...
# 5094   ZUMZ                             Zumiez Inc.              3.434064e+08
# 5095    ZUO                     Zuora, Inc. Class A              1.168405e+09
# 5097    ZWS  Zurn Elkay Water Solutions Corporation              3.494993e+09
# 5099   ZYME                           Zymeworks Inc              5.251385e+08
# 5101   ZYXI                             Zynex, Inc.              4.026127e+08
#
#       Com Shs to Calc Diluted EPS  Close Price_latest  Close Price_1M  \
# 1                      65617000.0             10.6000         10.1400
# 3                     113858684.0             50.2300         47.0600
# 9                      24687324.0             44.9200         49.4200
# 10                     38479437.0              3.7500          5.0000
# 11                    192837000.0              0.7489          0.9258
# ...                           ...                 ...             ...
# 5094                   19428000.0             17.6200         23.7000
# 5095                  131441000.0              9.3100          8.6200
# 5097                  153837000.0             19.8500         22.9700
# 5099                   65249184.0              8.2000          8.6200
# 5101                   39127000.0             10.9900         12.8200
#
#       Close Price_3M  Close Price_6M  Close Price_1Y  EBITDA Margin  ...  \
# 1             9.6100          6.1500           13.50       3.928522  ...
# 3            34.2400         28.9100           67.79     -19.407390  ...
# 9            54.2600         47.8300           48.58            NaN  ...
# 10            5.0000          6.0800            8.19     -24.133530  ...
# 11            0.8842          0.9696            2.41     -49.078670  ...
# ...              ...             ...             ...            ...  ...
# 5094         21.0100         21.8800           39.74       3.160622  ...
# 5095          5.8000          7.3400           14.97      10.034270  ...
# 5097         21.4300         24.8800           35.50      22.055150  ...
# 5099          8.0400          5.2700            7.00    -243.809100  ...
# 5101         13.8100          8.3900            6.32      14.308800  ...
#
#       Price / Earns Ratio  Price / Book Value  Entrpr Value/ Sales  \
# 1               21.249723            1.214968             0.406217
# 3                     NaN            5.209733             7.380912
# 9               10.875978            1.515298             4.238425
# 10                    NaN            1.347380             0.673363
# 11                    NaN            2.064364             2.624728
# ...                   ...                 ...                  ...
# 5094            23.783135            1.232033             0.606312
# 5095                  NaN                 NaN             2.303370
# 5097            57.085020            2.316369             2.893082
# 5099             4.132275            1.028174             0.118201
# 5101            31.925637            7.719286             3.484112
#
#       Entrpr Value/ EBITDA  Entrpr Value/ EBIT  Div Yield  Total Debt% Equity  \
# 1                 8.289439           17.830235   0.000000           58.710781
# 3                      NaN                 NaN   0.000000           11.812203
# 9                      NaN                 NaN   2.373328           39.404538
# 10                     NaN                 NaN   0.000000           16.516464
# 11                     NaN                 NaN   0.000000            7.013285
# ...                    ...                 ...        ...                 ...
# 5094              2.673720            9.842831   0.000000           62.430032
# 5095                   NaN                 NaN        NaN          148.745091
# 5097             20.704817           29.916347   0.945626           35.882353
# 5099              0.137113            0.148916        NaN            5.706189
# 5101             19.916418           23.326121   0.000000           40.626601
#
#       EBIT Interest Coverage  Current Ratio  Total Insider Purchases
# 1                   7.524440       1.310658                  25000.0
# 3                -343.966387       4.849187                      0.0
# 9                        NaN       0.030762                   1000.0
# 10              -3232.818182       6.236583                      0.0
# 11               -142.042493       3.426410                      0.0
# ...                      ...            ...                      ...
# 5094                     NaN       2.333038                      0.0
# 5095               -6.418291       2.131704                      0.0
# 5097                4.553903       2.618389                      0.0
# 5099                     NaN       5.696272                2318900.0
# 5101               52.131818       3.298824                      0.0
#
# [3686 rows x 27 columns]

# %%
# drop the rows that have outlier valuations

# define the list of columns to clean
cols_to_clean = ['Price /Sales CFY', 'Price / Earns Ratio', 'Price / Book Value', 'Entrpr Value/ Sales', 'Entrpr Value/ EBITDA', 'Entrpr Value/ EBIT']

# loop through each column and drop the outliers
for col in cols_to_clean:
    q_low = df[col].quantile(0.001)
    q_high = df[col].quantile(0.999)
    df = df[(df[col] >= q_low) & (df[col] <= q_high)]
# 3686 to 1729 rows

# %%
df
# Out:
#      Symbol                                    Name  Sec Market Value (LOCAL)  \
# 1      FLWS         1-800-FLOWERS.COM, Inc. Class A              3.996080e+08
# 19      MMM                              3M Company              5.567757e+10
# 32     AMRK            A-Mark Precious Metals, Inc.              7.654299e+08
# 33      AOS                 A. O. Smith Corporation              8.467280e+09
# 34     ATEN                      A10 Networks, Inc.              1.109844e+09
# ...     ...                                     ...                       ...
# 5091     ZI               ZoomInfo Technologies Inc              9.371473e+09
# 5094   ZUMZ                             Zumiez Inc.              3.434064e+08
# 5097    ZWS  Zurn Elkay Water Solutions Corporation              3.494993e+09
# 5099   ZYME                           Zymeworks Inc              5.251385e+08
# 5101   ZYXI                             Zynex, Inc.              4.026127e+08
#
#       Com Shs to Calc Diluted EPS  Close Price_latest  Close Price_1M  \
# 1                      65617000.0               10.60           10.14
# 19                    567600000.0              101.14          107.80
# 32                     24329500.0               32.53           29.82
# 33                    155779364.0               66.74           64.90
# 34                     77751000.0               14.98           14.80
# ...                           ...                 ...             ...
# 5091                  403392458.0               23.18           25.19
# 5094                   19428000.0               17.62           23.70
# 5097                  153837000.0               19.85           22.97
# 5099                   65249184.0                8.20            8.62
# 5101                   39127000.0               10.99           12.82
#
#       Close Price_3M  Close Price_6M  Close Price_1Y  EBITDA Margin  ...  \
# 1               9.61            6.15           13.50       3.928522  ...
# 19            120.14          112.99          150.46      24.811880  ...
# 32             34.41           26.49           39.70       2.364319  ...
# 33             56.90           49.83           66.97      19.956220  ...
# 34             17.02           13.00           13.93      20.809880  ...
# ...              ...             ...             ...            ...  ...
# 5091           28.80           40.04           56.41      44.233290  ...
# 5094           21.01           21.88           39.74       3.160622  ...
# 5097           21.43           24.88           35.50      22.055150  ...
# 5099            8.04            5.27            7.00    -243.809100  ...
# 5101           13.81            8.39            6.32      14.308800  ...
#
#       Price / Earns Ratio  Price / Book Value  Entrpr Value/ Sales  \
# 1               21.249723            1.214968             0.406217
# 19              11.782391            4.473949             2.368973
# 32               5.920147            1.543159             0.162685
# 33              37.832122            4.951360             2.347375
# 34              27.565059            7.113039             4.150875
# ...                   ...                 ...                  ...
# 5091           192.150606            5.355431            11.761700
# 5094            23.783135            1.232033             0.606312
# 5097            57.085020            2.316369             2.893082
# 5099             4.132275            1.028174             0.118201
# 5101            31.925637            7.719286             3.484112
#
#       Entrpr Value/ EBITDA  Entrpr Value/ EBIT  Div Yield  Total Debt% Equity  \
# 1                 8.289439           17.830235   0.000000           58.710781
# 19               13.591902           19.702085   4.969980          114.563239
# 32                9.524190           11.860207   0.000000          134.759695
# 33               12.002065           13.412024   1.991614           21.559764
# 34               18.888689           21.515291   1.262778           11.953904
# ...                    ...                 ...        ...                 ...
# 5091             47.365856           70.066304   0.000000           57.835197
# 5094              2.673720            9.842831   0.000000           62.430032
# 5097             20.704817           29.916347   0.945626           35.882353
# 5099              0.137113            0.148916        NaN            5.706189
# 5101             19.916418           23.326121   0.000000           40.626601
#
#       EBIT Interest Coverage  Current Ratio  Total Insider Purchases
# 1                   7.524440       1.310658                  25000.0
# 19                  8.178715       1.542371                      0.0
# 32                  5.061159       1.411588                      0.0
# 33                 69.638298       1.748769                   4000.0
# 34                       NaN       2.121364                      0.0
# ...                      ...            ...                      ...
# 5091                3.848739       1.452768                      0.0
# 5094                     NaN       2.333038                      0.0
# 5097                4.553903       2.618389                      0.0
# 5099                     NaN       5.696272                2318900.0
# 5101               52.131818       3.298824                      0.0
#
# [1729 rows x 27 columns]

# %%
# drop the rows that have outlier profitability

# define the list of columns to clean
cols_to_clean = ['EBITDA Margin', 'EBIT Margin', 'Net Income Margin', 'ROA', 'ROE', 'ROIC', 'Asset Turnover']

# loop through each column and drop the outliers
'''
for col in cols_to_clean:
    q_low = df[col].quantile(0.001)
    q_high = df[col].quantile(0.9999)
    df = df[(df[col] >= q_low) & (df[col] <= q_high)]
'''
# 1729 to 864 rows
# Out:
# '\nfor col in cols_to_clean:\n    q_low = df[col].quantile(0.001)\n    q_high = df[col].quantile(0.9999)\n    df = df[(df[col] >= q_low) & (df[col] <= q_high)]\n'

# %%
# define the list of columns to clean
cols_to_clean = ['EBITDA Margin', 'EBIT Margin', 'Net Income Margin', 'ROA', 'ROE', 'ROIC', 'Asset Turnover']

# loop through each column and drop the outliers
for col in cols_to_clean:
    q_low = df[col].quantile(0.001)
    
    df = df[(df[col] >= q_low)]

# %%
df
# Out:
#      Symbol                                     Name  \
# 19      MMM                               3M Company
# 33      AOS                  A. O. Smith Corporation
# 39      ABT                      Abbott Laboratories
# 40     ABBV                             AbbVie, Inc.
# 41     ABCM                  Abcam PLC Sponsored ADR
# ...     ...                                      ...
# 5081    ZBH             Zimmer Biomet Holdings, Inc.
# 5086    ZIP               ZipRecruiter, Inc. Class A
# 5089    ZTS                     Zoetis, Inc. Class A
# 5090     ZM  Zoom Video Communications, Inc. Class A
# 5091     ZI                ZoomInfo Technologies Inc
#
#       Sec Market Value (LOCAL)  Com Shs to Calc Diluted EPS  \
# 19                5.567757e+10                 5.676000e+08
# 33                8.467280e+09                 1.557794e+08
# 39                1.704056e+11                 1.764000e+09
# 40                2.796006e+11                 1.778000e+09
# 41                2.976440e+09                 2.289000e+08
# ...                        ...                          ...
# 5081              2.647650e+10                 2.103000e+08
# 5086              1.138849e+09                 1.213980e+08
# 5089              7.607883e+10                 4.703850e+08
# 5090              1.695982e+10                 3.042314e+08
# 5091              9.371473e+09                 4.033925e+08
#
#       Close Price_latest  Close Price_1M  Close Price_3M  Close Price_6M  \
# 19                101.14          107.80          120.14          112.99
# 33                 66.74           64.90           56.90           49.83
# 39                 98.05          100.46          108.18          100.68
# 40                158.02          152.71          163.10          143.06
# 41                 12.98           14.26           15.45           14.63
# ...                  ...             ...             ...             ...
# 5081              126.04          122.70          126.69          106.21
# 5086               15.22           17.35           16.26           15.81
# 5089              164.18          166.33          145.76          150.05
# 5090               69.04           73.93           65.89           74.45
# 5091               23.18           25.19           28.80           40.04
#
#       Close Price_1Y  EBITDA Margin  ...  Price / Earns Ratio  \
# 19            150.46       24.81188  ...            11.782391
# 33             66.97       19.95622  ...            37.832122
# 39            118.95       25.70148  ...            28.047721
# 40            161.33       48.39309  ...            24.388072
# 41             18.04       33.54594  ...           882.022472
# ...              ...            ...  ...                  ...
# 5081          125.28       34.33426  ...           115.877488
# 5086           22.76       23.40767  ...            32.418559
# 5089          189.43       42.96776  ...            32.608696
# 5090          113.93       38.89104  ...           220.005867
# 5091           56.41       44.23329  ...           192.150606
#
#       Price / Book Value  Entrpr Value/ Sales  Entrpr Value/ EBITDA  \
# 19              4.473949             2.368973             13.591902
# 33              4.951360             2.347375             12.002065
# 39              5.200690             4.619718             17.240654
# 40             16.571080             5.896882             10.989011
# 41              6.056398            12.847576             58.726456
# ...                  ...                  ...                   ...
# 5081            2.216875             4.663043             15.092388
# 5086           59.955450             2.192017             17.487152
# 5089           16.697430             9.094669             21.590310
# 5090            3.550524             3.980920             28.230689
# 5091            5.355431            11.761700             47.365856
#
#       Entrpr Value/ EBIT  Div Yield  Total Debt% Equity  \
# 19             19.702085   4.969980          114.563239
# 33             13.412024   1.991614           21.559764
# 39             23.976508   1.748793           48.917843
# 40             15.105636   3.533197          372.035470
# 41            144.718764   0.000000           35.009907
# ...                  ...        ...                 ...
# 5081           26.712724   0.752941           49.223397
# 5086           20.205693   0.000000         1956.694619
# 5089           25.019099   0.921187          184.631101
# 5090           70.861814   0.000000            1.554424
# 5091           70.066304   0.000000           57.835197
#
#       EBIT Interest Coverage  Current Ratio  Total Insider Purchases
# 19                  8.178715       1.542371                      0.0
# 33                 69.638298       1.748769                   4000.0
# 39                 26.546032       1.628511                      0.0
# 40                  9.634271       0.963606                      0.0
# 41                 10.370371       1.121481                      0.0
# ...                      ...            ...                      ...
# 5081                7.332115       1.877406                      0.0
# 5086                3.411748       4.838882                      0.0
# 5089               11.348837       2.370066                      0.0
# 5090                     NaN       3.527555                      0.0
# 5091                3.848739       1.452768                      0.0
#
# [869 rows x 27 columns]

# %%
# 6. drop the columns which have more than 40% missing values
# what metrics were dropped?
dropped_cols = []
for col in df.columns:
    if df[col].isna().sum() > len(df)*0.4:
        df.drop(col, axis=1, inplace=True)
        dropped_cols.append(col)

print("Dropped columns:", dropped_cols)
# dropped columns (metrics):
# Out:
# Dropped columns: []

# %%
# Calculate the percentage of missing values in each column
missing_perc = df.isna().mean() * 100

# Get the column names where the percentage of missing values is greater than 40%
columns_to_drop = missing_perc[missing_perc > 40].index

# Drop the columns from the dataframe
df = df.drop(columns_to_drop, axis=1)

# %%
df
# Out:
#      Symbol                                     Name  \
# 19      MMM                               3M Company
# 33      AOS                  A. O. Smith Corporation
# 39      ABT                      Abbott Laboratories
# 40     ABBV                             AbbVie, Inc.
# 41     ABCM                  Abcam PLC Sponsored ADR
# ...     ...                                      ...
# 5081    ZBH             Zimmer Biomet Holdings, Inc.
# 5086    ZIP               ZipRecruiter, Inc. Class A
# 5089    ZTS                     Zoetis, Inc. Class A
# 5090     ZM  Zoom Video Communications, Inc. Class A
# 5091     ZI                ZoomInfo Technologies Inc
#
#       Sec Market Value (LOCAL)  Com Shs to Calc Diluted EPS  \
# 19                5.567757e+10                 5.676000e+08
# 33                8.467280e+09                 1.557794e+08
# 39                1.704056e+11                 1.764000e+09
# 40                2.796006e+11                 1.778000e+09
# 41                2.976440e+09                 2.289000e+08
# ...                        ...                          ...
# 5081              2.647650e+10                 2.103000e+08
# 5086              1.138849e+09                 1.213980e+08
# 5089              7.607883e+10                 4.703850e+08
# 5090              1.695982e+10                 3.042314e+08
# 5091              9.371473e+09                 4.033925e+08
#
#       Close Price_latest  Close Price_1M  Close Price_3M  Close Price_6M  \
# 19                101.14          107.80          120.14          112.99
# 33                 66.74           64.90           56.90           49.83
# 39                 98.05          100.46          108.18          100.68
# 40                158.02          152.71          163.10          143.06
# 41                 12.98           14.26           15.45           14.63
# ...                  ...             ...             ...             ...
# 5081              126.04          122.70          126.69          106.21
# 5086               15.22           17.35           16.26           15.81
# 5089              164.18          166.33          145.76          150.05
# 5090               69.04           73.93           65.89           74.45
# 5091               23.18           25.19           28.80           40.04
#
#       Close Price_1Y  EBITDA Margin  ...  Price / Earns Ratio  \
# 19            150.46       24.81188  ...            11.782391
# 33             66.97       19.95622  ...            37.832122
# 39            118.95       25.70148  ...            28.047721
# 40            161.33       48.39309  ...            24.388072
# 41             18.04       33.54594  ...           882.022472
# ...              ...            ...  ...                  ...
# 5081          125.28       34.33426  ...           115.877488
# 5086           22.76       23.40767  ...            32.418559
# 5089          189.43       42.96776  ...            32.608696
# 5090          113.93       38.89104  ...           220.005867
# 5091           56.41       44.23329  ...           192.150606
#
#       Price / Book Value  Entrpr Value/ Sales  Entrpr Value/ EBITDA  \
# 19              4.473949             2.368973             13.591902
# 33              4.951360             2.347375             12.002065
# 39              5.200690             4.619718             17.240654
# 40             16.571080             5.896882             10.989011
# 41              6.056398            12.847576             58.726456
# ...                  ...                  ...                   ...
# 5081            2.216875             4.663043             15.092388
# 5086           59.955450             2.192017             17.487152
# 5089           16.697430             9.094669             21.590310
# 5090            3.550524             3.980920             28.230689
# 5091            5.355431            11.761700             47.365856
#
#       Entrpr Value/ EBIT  Div Yield  Total Debt% Equity  \
# 19             19.702085   4.969980          114.563239
# 33             13.412024   1.991614           21.559764
# 39             23.976508   1.748793           48.917843
# 40             15.105636   3.533197          372.035470
# 41            144.718764   0.000000           35.009907
# ...                  ...        ...                 ...
# 5081           26.712724   0.752941           49.223397
# 5086           20.205693   0.000000         1956.694619
# 5089           25.019099   0.921187          184.631101
# 5090           70.861814   0.000000            1.554424
# 5091           70.066304   0.000000           57.835197
#
#       EBIT Interest Coverage  Current Ratio  Total Insider Purchases
# 19                  8.178715       1.542371                      0.0
# 33                 69.638298       1.748769                   4000.0
# 39                 26.546032       1.628511                      0.0
# 40                  9.634271       0.963606                      0.0
# 41                 10.370371       1.121481                      0.0
# ...                      ...            ...                      ...
# 5081                7.332115       1.877406                      0.0
# 5086                3.411748       4.838882                      0.0
# 5089               11.348837       2.370066                      0.0
# 5090                     NaN       3.527555                      0.0
# 5091                3.848739       1.452768                      0.0
#
# [869 rows x 27 columns]

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#     Symbol                                     Name  Sec Market Value (LOCAL)  \
# 0      MMM                               3M Company              5.567757e+10
# 1      AOS                  A. O. Smith Corporation              8.467280e+09
# 2      ABT                      Abbott Laboratories              1.704056e+11
# 3     ABBV                             AbbVie, Inc.              2.796006e+11
# 4     ABCM                  Abcam PLC Sponsored ADR              2.976440e+09
# ..     ...                                      ...                       ...
# 864    ZBH             Zimmer Biomet Holdings, Inc.              2.647650e+10
# 865    ZIP               ZipRecruiter, Inc. Class A              1.138849e+09
# 866    ZTS                     Zoetis, Inc. Class A              7.607883e+10
# 867     ZM  Zoom Video Communications, Inc. Class A              1.695982e+10
# 868     ZI                ZoomInfo Technologies Inc              9.371473e+09
#
#      Com Shs to Calc Diluted EPS  Close Price_latest  Close Price_1M  \
# 0                   5.676000e+08              101.14          107.80
# 1                   1.557794e+08               66.74           64.90
# 2                   1.764000e+09               98.05          100.46
# 3                   1.778000e+09              158.02          152.71
# 4                   2.289000e+08               12.98           14.26
# ..                           ...                 ...             ...
# 864                 2.103000e+08              126.04          122.70
# 865                 1.213980e+08               15.22           17.35
# 866                 4.703850e+08              164.18          166.33
# 867                 3.042314e+08               69.04           73.93
# 868                 4.033925e+08               23.18           25.19
#
#      Close Price_3M  Close Price_6M  Close Price_1Y  EBITDA Margin  ...  \
# 0            120.14          112.99          150.46       24.81188  ...
# 1             56.90           49.83           66.97       19.95622  ...
# 2            108.18          100.68          118.95       25.70148  ...
# 3            163.10          143.06          161.33       48.39309  ...
# 4             15.45           14.63           18.04       33.54594  ...
# ..              ...             ...             ...            ...  ...
# 864          126.69          106.21          125.28       34.33426  ...
# 865           16.26           15.81           22.76       23.40767  ...
# 866          145.76          150.05          189.43       42.96776  ...
# 867           65.89           74.45          113.93       38.89104  ...
# 868           28.80           40.04           56.41       44.23329  ...
#
#      Price / Earns Ratio  Price / Book Value  Entrpr Value/ Sales  \
# 0              11.782391            4.473949             2.368973
# 1              37.832122            4.951360             2.347375
# 2              28.047721            5.200690             4.619718
# 3              24.388072           16.571080             5.896882
# 4             882.022472            6.056398            12.847576
# ..                   ...                 ...                  ...
# 864           115.877488            2.216875             4.663043
# 865            32.418559           59.955450             2.192017
# 866            32.608696           16.697430             9.094669
# 867           220.005867            3.550524             3.980920
# 868           192.150606            5.355431            11.761700
#
#      Entrpr Value/ EBITDA  Entrpr Value/ EBIT  Div Yield  Total Debt% Equity  \
# 0               13.591902           19.702085   4.969980          114.563239
# 1               12.002065           13.412024   1.991614           21.559764
# 2               17.240654           23.976508   1.748793           48.917843
# 3               10.989011           15.105636   3.533197          372.035470
# 4               58.726456          144.718764   0.000000           35.009907
# ..                    ...                 ...        ...                 ...
# 864             15.092388           26.712724   0.752941           49.223397
# 865             17.487152           20.205693   0.000000         1956.694619
# 866             21.590310           25.019099   0.921187          184.631101
# 867             28.230689           70.861814   0.000000            1.554424
# 868             47.365856           70.066304   0.000000           57.835197
#
#      EBIT Interest Coverage  Current Ratio  Total Insider Purchases
# 0                  8.178715       1.542371                      0.0
# 1                 69.638298       1.748769                   4000.0
# 2                 26.546032       1.628511                      0.0
# 3                  9.634271       0.963606                      0.0
# 4                 10.370371       1.121481                      0.0
# ..                      ...            ...                      ...
# 864                7.332115       1.877406                      0.0
# 865                3.411748       4.838882                      0.0
# 866               11.348837       2.370066                      0.0
# 867                     NaN       3.527555                      0.0
# 868                3.848739       1.452768                      0.0
#
# [869 rows x 27 columns]

# %%
# 7.* impute missing values with median
imputer = SimpleImputer(strategy='median')
cols_to_impute = df.columns[2:]
df_imputed = pd.DataFrame(imputer.fit_transform(df[cols_to_impute]), columns=cols_to_impute)

# add back the columns of symbol & name
df_imputed[['Symbol', 'Name']] = df[['Symbol', 'Name']]

# Move Symbol and Name back to the leftmost position & check the resulting dataframe
cols = ['Symbol', 'Name'] + [col for col in df_imputed.columns if col not in ['Symbol', 'Name']]
df_imp = df_imputed[cols]
df_imp
# Out:
#     Symbol                                     Name  Sec Market Value (LOCAL)  \
# 0      MMM                               3M Company              5.567757e+10
# 1      AOS                  A. O. Smith Corporation              8.467280e+09
# 2      ABT                      Abbott Laboratories              1.704056e+11
# 3     ABBV                             AbbVie, Inc.              2.796006e+11
# 4     ABCM                  Abcam PLC Sponsored ADR              2.976440e+09
# ..     ...                                      ...                       ...
# 864    ZBH             Zimmer Biomet Holdings, Inc.              2.647650e+10
# 865    ZIP               ZipRecruiter, Inc. Class A              1.138849e+09
# 866    ZTS                     Zoetis, Inc. Class A              7.607883e+10
# 867     ZM  Zoom Video Communications, Inc. Class A              1.695982e+10
# 868     ZI                ZoomInfo Technologies Inc              9.371473e+09
#
#      Com Shs to Calc Diluted EPS  Close Price_latest  Close Price_1M  \
# 0                   5.676000e+08              101.14          107.80
# 1                   1.557794e+08               66.74           64.90
# 2                   1.764000e+09               98.05          100.46
# 3                   1.778000e+09              158.02          152.71
# 4                   2.289000e+08               12.98           14.26
# ..                           ...                 ...             ...
# 864                 2.103000e+08              126.04          122.70
# 865                 1.213980e+08               15.22           17.35
# 866                 4.703850e+08              164.18          166.33
# 867                 3.042314e+08               69.04           73.93
# 868                 4.033925e+08               23.18           25.19
#
#      Close Price_3M  Close Price_6M  Close Price_1Y  EBITDA Margin  ...  \
# 0            120.14          112.99          150.46       24.81188  ...
# 1             56.90           49.83           66.97       19.95622  ...
# 2            108.18          100.68          118.95       25.70148  ...
# 3            163.10          143.06          161.33       48.39309  ...
# 4             15.45           14.63           18.04       33.54594  ...
# ..              ...             ...             ...            ...  ...
# 864          126.69          106.21          125.28       34.33426  ...
# 865           16.26           15.81           22.76       23.40767  ...
# 866          145.76          150.05          189.43       42.96776  ...
# 867           65.89           74.45          113.93       38.89104  ...
# 868           28.80           40.04           56.41       44.23329  ...
#
#      Price / Earns Ratio  Price / Book Value  Entrpr Value/ Sales  \
# 0              11.782391            4.473949             2.368973
# 1              37.832122            4.951360             2.347375
# 2              28.047721            5.200690             4.619718
# 3              24.388072           16.571080             5.896882
# 4             882.022472            6.056398            12.847576
# ..                   ...                 ...                  ...
# 864           115.877488            2.216875             4.663043
# 865            32.418559           59.955450             2.192017
# 866            32.608696           16.697430             9.094669
# 867           220.005867            3.550524             3.980920
# 868           192.150606            5.355431            11.761700
#
#      Entrpr Value/ EBITDA  Entrpr Value/ EBIT  Div Yield  Total Debt% Equity  \
# 0               13.591902           19.702085   4.969980          114.563239
# 1               12.002065           13.412024   1.991614           21.559764
# 2               17.240654           23.976508   1.748793           48.917843
# 3               10.989011           15.105636   3.533197          372.035470
# 4               58.726456          144.718764   0.000000           35.009907
# ..                    ...                 ...        ...                 ...
# 864             15.092388           26.712724   0.752941           49.223397
# 865             17.487152           20.205693   0.000000         1956.694619
# 866             21.590310           25.019099   0.921187          184.631101
# 867             28.230689           70.861814   0.000000            1.554424
# 868             47.365856           70.066304   0.000000           57.835197
#
#      EBIT Interest Coverage  Current Ratio  Total Insider Purchases
# 0                  8.178715       1.542371                      0.0
# 1                 69.638298       1.748769                   4000.0
# 2                 26.546032       1.628511                      0.0
# 3                  9.634271       0.963606                      0.0
# 4                 10.370371       1.121481                      0.0
# ..                      ...            ...                      ...
# 864                7.332115       1.877406                      0.0
# 865                3.411748       4.838882                      0.0
# 866               11.348837       2.370066                      0.0
# 867                7.808558       3.527555                      0.0
# 868                3.848739       1.452768                      0.0
#
# [869 rows x 27 columns]

# %%
df_imp.describe()
# Out:
#        Sec Market Value (LOCAL)  Com Shs to Calc Diluted EPS  \
# count              8.690000e+02                 8.690000e+02
# mean               3.318546e+10                 3.595120e+08
# std                1.271113e+11                 9.410353e+08
# min                3.947590e+07                 2.889991e+06
# 25%                2.976440e+09                 6.457900e+07
# 50%                7.302719e+09                 1.393063e+08
# 75%                2.478352e+10                 3.164590e+08
# max                2.535467e+12                 1.632582e+10
#
#        Close Price_latest  Close Price_1M  Close Price_3M  Close Price_6M  \
# count          869.000000      869.000000      869.000000      869.000000
# mean           106.378441      109.029833      103.109969       95.430762
# std            232.281936      222.961970      201.501123      181.413775
# min              1.310000        1.470000        2.540000        4.550000
# 25%             26.910000       28.640000       28.380000       26.380000
# 50%             59.560000       63.150000       59.830000       56.300000
# 75%            124.620000      125.130000      120.140000      111.260000
# max           5413.000000     5132.470000     4645.000000     4057.670000
#
#        Close Price_1Y  EBITDA Margin  EBIT Margin  Net Income Margin  ...  \
# count      869.000000     869.000000   869.000000         869.000000  ...
# mean       115.655953      30.014207    21.415101          13.821599  ...
# std        215.910629      22.532966    17.512429          12.226260  ...
# min          5.570000      -0.160335   -12.500360           0.158631  ...
# 25%         33.110000      14.575710    10.143180           5.551376  ...
# 50%         66.860000      23.706440    17.368140          10.266278  ...
# 75%        135.710000      38.511310    28.075340          18.049683  ...
# max       4668.040000     252.649900   252.649900         103.992766  ...
#
#        Price / Earns Ratio  Price / Book Value  Entrpr Value/ Sales  \
# count           869.000000          869.000000           869.000000
# mean             43.534045            5.638180             4.028703
# std             175.723125           12.556074             4.127693
# min               0.413225            0.324731             0.122537
# 25%              12.377991            1.657370             1.311132
# 50%              20.664215            2.702466             2.567181
# 75%              32.653679            5.051855             5.037833
# max            4474.012462          205.990600            41.787142
#
#        Entrpr Value/ EBITDA  Entrpr Value/ EBIT   Div Yield  \
# count            869.000000          869.000000  869.000000
# mean              14.316967           23.830760    1.956509
# std               13.237136           31.147655    2.810959
# min                1.080138            1.210528    0.000000
# 25%                7.384254           10.871730    0.000000
# 50%               12.308956           17.783574    1.204365
# 75%               17.236082           26.307501    2.766861
# max              211.387959          566.699636   33.801353
#
#        Total Debt% Equity  EBIT Interest Coverage  Current Ratio  \
# count          869.000000              869.000000     869.000000
# mean           169.388866               60.351610       1.883659
# std            369.827741             1066.498282       1.499038
# min              0.000000                0.383506       0.332947
# 25%             50.727489                3.694915       1.145546
# 50%             87.871975                7.808558       1.527531
# 75%            157.574905               16.196179       2.097131
# max           6895.756441            31236.439020      18.583703
#
#        Total Insider Purchases
# count             8.690000e+02
# mean              7.179073e+04
# std               8.402508e+05
# min               0.000000e+00
# 25%               0.000000e+00
# 50%               0.000000e+00
# 75%               0.000000e+00
# max               1.967395e+07
#
# [8 rows x 25 columns]

# %%
# create a new DataFrame to record our attribute-group metrics
df_2 = pd.DataFrame({
    'Symbol': df['Symbol'],
    'Name': df['Name'],
    'Insider Buying %' : df_imp['Total Insider Purchases'] / df_imp['Com Shs to Calc Diluted EPS'] * 100
})

df_2
# Out:
#     Symbol                                     Name  Insider Buying %
# 0      MMM                               3M Company          0.000000
# 1      AOS                  A. O. Smith Corporation          0.002568
# 2      ABT                      Abbott Laboratories          0.000000
# 3     ABBV                             AbbVie, Inc.          0.000000
# 4     ABCM                  Abcam PLC Sponsored ADR          0.000000
# ..     ...                                      ...               ...
# 864    ZBH             Zimmer Biomet Holdings, Inc.          0.000000
# 865    ZIP               ZipRecruiter, Inc. Class A          0.000000
# 866    ZTS                     Zoetis, Inc. Class A          0.000000
# 867     ZM  Zoom Video Communications, Inc. Class A          0.000000
# 868     ZI                ZoomInfo Technologies Inc          0.000000
#
# [869 rows x 3 columns]

# %%
# calculate returns for different time periods
df_imp['Return_1M'] = (df_imp['Close Price_latest'] - df_imp['Close Price_1M']) / df['Close Price_1M']
df_imp['Return_3M'] = (df_imp['Close Price_latest'] - df_imp['Close Price_3M']) / df['Close Price_3M']
df_imp['Return_6M'] = (df_imp['Close Price_latest'] - df_imp['Close Price_6M']) / df['Close Price_6M']
df_imp['Return_1Y'] = (df_imp['Close Price_latest'] - df_imp['Close Price_1Y']) / df['Close Price_1Y']
df_imp
# Out:
# C:\Users\l3047\AppData\Local\Temp\ipykernel_18764\4052276547.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_imp['Return_1M'] = (df_imp['Close Price_latest'] - df_imp['Close Price_1M']) / df['Close Price_1M']
# C:\Users\l3047\AppData\Local\Temp\ipykernel_18764\4052276547.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_imp['Return_3M'] = (df_imp['Close Price_latest'] - df_imp['Close Price_3M']) / df['Close Price_3M']
# C:\Users\l3047\AppData\Local\Temp\ipykernel_18764\4052276547.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_imp['Return_6M'] = (df_imp['Close Price_latest'] - df_imp['Close Price_6M']) / df['Close Price_6M']
# C:\Users\l3047\AppData\Local\Temp\ipykernel_18764\4052276547.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_imp['Return_1Y'] = (df_imp['Close Price_latest'] - df_imp['Close Price_1Y']) / df['Close Price_1Y']
#     Symbol                                     Name  Sec Market Value (LOCAL)  \
# 0      MMM                               3M Company              5.567757e+10
# 1      AOS                  A. O. Smith Corporation              8.467280e+09
# 2      ABT                      Abbott Laboratories              1.704056e+11
# 3     ABBV                             AbbVie, Inc.              2.796006e+11
# 4     ABCM                  Abcam PLC Sponsored ADR              2.976440e+09
# ..     ...                                      ...                       ...
# 864    ZBH             Zimmer Biomet Holdings, Inc.              2.647650e+10
# 865    ZIP               ZipRecruiter, Inc. Class A              1.138849e+09
# 866    ZTS                     Zoetis, Inc. Class A              7.607883e+10
# 867     ZM  Zoom Video Communications, Inc. Class A              1.695982e+10
# 868     ZI                ZoomInfo Technologies Inc              9.371473e+09
#
#      Com Shs to Calc Diluted EPS  Close Price_latest  Close Price_1M  \
# 0                   5.676000e+08              101.14          107.80
# 1                   1.557794e+08               66.74           64.90
# 2                   1.764000e+09               98.05          100.46
# 3                   1.778000e+09              158.02          152.71
# 4                   2.289000e+08               12.98           14.26
# ..                           ...                 ...             ...
# 864                 2.103000e+08              126.04          122.70
# 865                 1.213980e+08               15.22           17.35
# 866                 4.703850e+08              164.18          166.33
# 867                 3.042314e+08               69.04           73.93
# 868                 4.033925e+08               23.18           25.19
#
#      Close Price_3M  Close Price_6M  Close Price_1Y  EBITDA Margin  ...  \
# 0            120.14          112.99          150.46       24.81188  ...
# 1             56.90           49.83           66.97       19.95622  ...
# 2            108.18          100.68          118.95       25.70148  ...
# 3            163.10          143.06          161.33       48.39309  ...
# 4             15.45           14.63           18.04       33.54594  ...
# ..              ...             ...             ...            ...  ...
# 864          126.69          106.21          125.28       34.33426  ...
# 865           16.26           15.81           22.76       23.40767  ...
# 866          145.76          150.05          189.43       42.96776  ...
# 867           65.89           74.45          113.93       38.89104  ...
# 868           28.80           40.04           56.41       44.23329  ...
#
#      Entrpr Value/ EBIT  Div Yield  Total Debt% Equity  \
# 0             19.702085   4.969980          114.563239
# 1             13.412024   1.991614           21.559764
# 2             23.976508   1.748793           48.917843
# 3             15.105636   3.533197          372.035470
# 4            144.718764   0.000000           35.009907
# ..                  ...        ...                 ...
# 864           26.712724   0.752941           49.223397
# 865           20.205693   0.000000         1956.694619
# 866           25.019099   0.921187          184.631101
# 867           70.861814   0.000000            1.554424
# 868           70.066304   0.000000           57.835197
#
#      EBIT Interest Coverage  Current Ratio  Total Insider Purchases  \
# 0                  8.178715       1.542371                      0.0
# 1                 69.638298       1.748769                   4000.0
# 2                 26.546032       1.628511                      0.0
# 3                  9.634271       0.963606                      0.0
# 4                 10.370371       1.121481                      0.0
# ..                      ...            ...                      ...
# 864                7.332115       1.877406                      0.0
# 865                3.411748       4.838882                      0.0
# 866               11.348837       2.370066                      0.0
# 867                7.808558       3.527555                      0.0
# 868                3.848739       1.452768                      0.0
#
#      Return_1M  Return_3M  Return_6M  Return_1Y
# 0    -0.061781  -0.158149  -0.104877  -0.327795
# 1     0.028351   0.172935   0.339354  -0.003434
# 2    -0.023990  -0.093640  -0.026122  -0.175704
# 3     0.034772  -0.031147   0.104572  -0.020517
# 4    -0.089762  -0.159871  -0.112782  -0.280488
# ..         ...        ...        ...        ...
# 864   0.027221  -0.005131   0.186706   0.006066
# 865  -0.122767  -0.063961  -0.037318  -0.331283
# 866  -0.012926   0.126372   0.094169  -0.133295
# 867  -0.066144   0.047807  -0.072666  -0.394014
# 868  -0.079794  -0.195139  -0.421079  -0.589080
#
# [869 rows x 31 columns]

# %% [markdown]
# # Return

# %%
# select the return attributes
return_df = df_imp[['Return_1M', 'Return_3M', 'Return_6M', 'Return_1Y']]

# standardize the data
scaler = StandardScaler()
return_df_scaled = scaler.fit_transform(return_df)
pca = PCA(n_components=1)

# perform PCA on the standardized data
pca = PCA(n_components=1)
return_pca = pca.fit_transform(return_df_scaled)

df_2['Return'] = return_pca.flatten()
df_2
# Out:
#     Symbol                                     Name  Insider Buying %  \
# 0      MMM                               3M Company          0.000000
# 1      AOS                  A. O. Smith Corporation          0.002568
# 2      ABT                      Abbott Laboratories          0.000000
# 3     ABBV                             AbbVie, Inc.          0.000000
# 4     ABCM                  Abcam PLC Sponsored ADR          0.000000
# ..     ...                                      ...               ...
# 864    ZBH             Zimmer Biomet Holdings, Inc.          0.000000
# 865    ZIP               ZipRecruiter, Inc. Class A          0.000000
# 866    ZTS                     Zoetis, Inc. Class A          0.000000
# 867     ZM  Zoom Video Communications, Inc. Class A          0.000000
# 868     ZI                ZoomInfo Technologies Inc          0.000000
#
#        Return
# 0   -1.390680
# 1    1.837912
# 2   -0.512445
# 3    0.600434
# 4   -1.482386
# ..        ...
# 864  0.888255
# 865 -1.249933
# 866  0.648456
# 867 -0.761540
# 868 -2.823167
#
# [869 rows x 4 columns]

# %% [markdown]
# # Profitability

# %%
# select the profitability metrics
profitability_df = df_imp[['EBITDA Margin', 'EBIT Margin', 'Net Income Margin', 'ROA', 'ROE','ROIC', 'Asset Turnover']]

# standardize the data
scaler = StandardScaler()
profitability_df_scaled = scaler.fit_transform(profitability_df)

# perform PCA on the standardized data
pca = PCA(n_components=1)
profitability_pca = pca.fit_transform(profitability_df_scaled)

df_2['Profitability'] = profitability_pca.flatten()
df_2
# Out:
#     Symbol                                     Name  Insider Buying %  \
# 0      MMM                               3M Company          0.000000
# 1      AOS                  A. O. Smith Corporation          0.002568
# 2      ABT                      Abbott Laboratories          0.000000
# 3     ABBV                             AbbVie, Inc.          0.000000
# 4     ABCM                  Abcam PLC Sponsored ADR          0.000000
# ..     ...                                      ...               ...
# 864    ZBH             Zimmer Biomet Holdings, Inc.          0.000000
# 865    ZIP               ZipRecruiter, Inc. Class A          0.000000
# 866    ZTS                     Zoetis, Inc. Class A          0.000000
# 867     ZM  Zoom Video Communications, Inc. Class A          0.000000
# 868     ZI                ZoomInfo Technologies Inc          0.000000
#
#        Return  Profitability
# 0   -1.390680      -0.048293
# 1    1.837912      -0.870505
# 2   -0.512445       0.168202
# 3    0.600434       1.653139
# 4   -1.482386       0.008200
# ..        ...            ...
# 864  0.888255       0.251236
# 865 -1.249933      -0.710111
# 866  0.648456       1.431559
# 867 -0.761540       0.447042
# 868 -2.823167       1.081686
#
# [869 rows x 5 columns]

# %% [markdown]
# # Valuation

# %%
# select the valuation metrics
valuation_df = df_imp[['Price /Sales CFY', 'Price / Earns Ratio','Price / Book Value', 'Entrpr Value/ Sales', 'Entrpr Value/ EBITDA', 'Entrpr Value/ EBIT']]

# standardize the data
scaler = StandardScaler()
valuation_df_scaled = scaler.fit_transform(valuation_df)

# perform PCA on the standardized data
pca = PCA(n_components=1)
valuation_pca = pca.fit_transform(valuation_df_scaled)

df_2['Valuation'] = valuation_pca.flatten()
df_2
# Out:
#     Symbol                                     Name  Insider Buying %  \
# 0      MMM                               3M Company          0.000000
# 1      AOS                  A. O. Smith Corporation          0.002568
# 2      ABT                      Abbott Laboratories          0.000000
# 3     ABBV                             AbbVie, Inc.          0.000000
# 4     ABCM                  Abcam PLC Sponsored ADR          0.000000
# ..     ...                                      ...               ...
# 864    ZBH             Zimmer Biomet Holdings, Inc.          0.000000
# 865    ZIP               ZipRecruiter, Inc. Class A          0.000000
# 866    ZTS                     Zoetis, Inc. Class A          0.000000
# 867     ZM  Zoom Video Communications, Inc. Class A          0.000000
# 868     ZI                ZoomInfo Technologies Inc          0.000000
#
#        Return  Profitability  Valuation
# 0   -1.390680      -0.048293  -0.486418
# 1    1.837912      -0.870505  -0.533664
# 2   -0.512445       0.168202   0.311572
# 3    0.600434       1.653139   0.283475
# 4   -1.482386       0.008200   7.280843
# ..        ...            ...        ...
# 864  0.888255       0.251236   0.333858
# 865 -1.249933      -0.710111   0.451222
# 866  0.648456       1.431559   1.652969
# 867 -0.761540       0.447042   1.816349
# 868 -2.823167       1.081686   4.076742
#
# [869 rows x 6 columns]

# %%
df_2['Valuation_inver'] = 28 - df_2['Valuation']
df_2
# Out:
#     Symbol                                     Name  Insider Buying %  \
# 0      MMM                               3M Company          0.000000
# 1      AOS                  A. O. Smith Corporation          0.002568
# 2      ABT                      Abbott Laboratories          0.000000
# 3     ABBV                             AbbVie, Inc.          0.000000
# 4     ABCM                  Abcam PLC Sponsored ADR          0.000000
# ..     ...                                      ...               ...
# 864    ZBH             Zimmer Biomet Holdings, Inc.          0.000000
# 865    ZIP               ZipRecruiter, Inc. Class A          0.000000
# 866    ZTS                     Zoetis, Inc. Class A          0.000000
# 867     ZM  Zoom Video Communications, Inc. Class A          0.000000
# 868     ZI                ZoomInfo Technologies Inc          0.000000
#
#        Return  Profitability  Valuation  Valuation_inver
# 0   -1.390680      -0.048293  -0.486418        28.486418
# 1    1.837912      -0.870505  -0.533664        28.533664
# 2   -0.512445       0.168202   0.311572        27.688428
# 3    0.600434       1.653139   0.283475        27.716525
# 4   -1.482386       0.008200   7.280843        20.719157
# ..        ...            ...        ...              ...
# 864  0.888255       0.251236   0.333858        27.666142
# 865 -1.249933      -0.710111   0.451222        27.548778
# 866  0.648456       1.431559   1.652969        26.347031
# 867 -0.761540       0.447042   1.816349        26.183651
# 868 -2.823167       1.081686   4.076742        23.923258
#
# [869 rows x 7 columns]

# %% [markdown]
# # Safety

# %%
# select the safety metrics
safety_df = df_imp[['Div Yield', 'EBIT Interest Coverage', 'Current Ratio']]

# standardize the data
scaler = StandardScaler()
safety_df_scaled = scaler.fit_transform(safety_df)

# perform PCA on the standardized data
pca = PCA(n_components=1)
safety_pca = pca.fit_transform(safety_df_scaled)

df_2['Safety'] = safety_pca.flatten()
df_2
# Out:
#     Symbol                                     Name  Insider Buying %  \
# 0      MMM                               3M Company          0.000000
# 1      AOS                  A. O. Smith Corporation          0.002568
# 2      ABT                      Abbott Laboratories          0.000000
# 3     ABBV                             AbbVie, Inc.          0.000000
# 4     ABCM                  Abcam PLC Sponsored ADR          0.000000
# ..     ...                                      ...               ...
# 864    ZBH             Zimmer Biomet Holdings, Inc.          0.000000
# 865    ZIP               ZipRecruiter, Inc. Class A          0.000000
# 866    ZTS                     Zoetis, Inc. Class A          0.000000
# 867     ZM  Zoom Video Communications, Inc. Class A          0.000000
# 868     ZI                ZoomInfo Technologies Inc          0.000000
#
#        Return  Profitability  Valuation  Valuation_inver    Safety
# 0   -1.390680      -0.048293  -0.486418        28.486418 -0.719834
# 1    1.837912      -0.870505  -0.533664        28.533664 -0.063003
# 2   -0.512445       0.168202   0.311572        27.688428 -0.095844
# 3    0.600434       1.653139   0.283475        27.716525 -0.725661
# 4   -1.482386       0.008200   7.280843        20.719157 -0.022086
# ..        ...            ...        ...              ...       ...
# 864  0.888255       0.251236   0.333858        27.666142  0.185753
# 865 -1.249933      -0.710111   0.451222        27.548778  1.665662
# 866  0.648456       1.431559   1.652969        26.347031  0.381828
# 867 -0.761540       0.447042   1.816349        26.183651  1.071273
# 868 -2.823167       1.081686   4.076742        23.923258  0.125375
#
# [869 rows x 8 columns]

# %%
df_2.describe()
# Out:
#        Insider Buying %        Return  Profitability     Valuation  \
# count        869.000000  8.690000e+02   8.690000e+02  8.690000e+02
# mean           0.048659 -1.584208e-17  -8.432074e-18 -2.759588e-17
# std            0.536138  1.637052e+00   1.690800e+00  1.836588e+00
# min            0.000000 -6.630035e+00  -4.657330e+00 -1.780347e+00
# 25%            0.000000 -9.210980e-01  -1.112785e+00 -1.035804e+00
# 50%            0.000000 -6.321626e-02  -2.797065e-01 -4.529294e-01
# 75%            0.000000  9.424435e-01   8.140261e-01  4.451869e-01
# max           10.465774  8.330588e+00   1.287445e+01  2.774441e+01
#
#        Valuation_inver        Safety
# count       869.000000  8.690000e+02
# mean         28.000000 -2.341178e-17
# std           1.836588  1.109318e+00
# min           0.255595 -5.771584e+00
# 25%          27.554813 -4.493316e-01
# 50%          28.452929 -6.791840e-02
# 75%          29.035804  3.035739e-01
# max          29.780347  1.892670e+01

# %% [markdown]
# # Final Factor Score Calculation

# %%
# assign weights to each dimension
w_insider_buying = 0.3
w_return = 0.2
w_profitability = 0.2
w_valuation_inver = 0.2
w_safety = 0.1

# calculate the weighted score for each stock
df_2['Weighted Score'] = (
    w_insider_buying * df_2['Insider Buying %'] +
    w_return * df_2['Return'] +
    w_profitability * df_2['Profitability'] +
    w_valuation_inver * df_2['Valuation_inver'] +
    w_safety * df_2['Safety']
    
)

# sort the stocks by weighted score in descending order
df_2 = df_2.sort_values(by=['Weighted Score'], ascending=False)

# select the top 10 stocks
top_10 = df_2.head(10)

top_10
# Out:
#     Symbol                                 Name  Insider Buying %    Return  \
# 751    SNX                TD SYNNEX Corporation         10.465774 -0.179794
# 512    MTH           Meritage Homes Corporation          0.000000  3.491797
# 222   PLAY  Dave & Buster's Entertainment, Inc.          8.658757 -0.431260
# 355   GRBK           Green Brick Partners, Inc.          0.000000  5.006145
# 693   STNG                 Scorpio Tankers Inc.          0.000000  3.510444
# 414   INSW          International Seaways, Inc.          0.000000  3.183814
# 506   MEDP               Medpace Holdings, Inc.          5.757952  0.370128
# 392    HHC            Howard Hughes Corporation          4.629329  0.105263
# 778    TPH               Tri Pointe Homes, Inc.          0.000000  3.387167
# 259    ELF                  e.l.f. Beauty, Inc.          0.000000  8.330588
#
#      Profitability  Valuation  Valuation_inver     Safety  Weighted Score
# 751      -2.711581  -1.335210        29.335210  -0.176269        8.410872
# 512      -0.607593  -1.582326        29.582326  18.926695        8.385975
# 222      -0.590260  -0.914324        28.914324  -0.322832        8.143905
# 355      -0.330342  -1.459355        29.459355   3.451792        7.172211
# 693       3.287565  -0.975748        28.975748  -0.006967        7.154055
# 414       3.345615  -0.994722        28.994722   0.398978        7.144728
# 506      -0.566936   0.798249        27.201751  -0.300466        7.098327
# 392       0.064434  -0.158156        28.158156   0.159111        7.070280
# 778      -0.604390  -1.590403        29.590403   5.586819        7.033318
# 259      -0.781231   0.922647        27.077353   0.819308        7.007273

# %%
ticker_list = top_10['Symbol'].tolist()
print(ticker_list)
# Out:
# ['SNX', 'MTH', 'PLAY', 'GRBK', 'STNG', 'INSW', 'MEDP', 'HHC', 'TPH', 'ELF']
